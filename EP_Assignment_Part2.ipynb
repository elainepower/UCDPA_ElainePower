# %% [markdown]
# # Tweet Content Analysis

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd
# %matplotlib notebook

# %%
pancake_mentions = pd.read_csv("PancakeMentions.csv")
pancake_mentions.head()
# Out:
#          Date     Time                                                URL  \
# 0  2022-03-08  06:45PM  https://twitter.com/MacyMaybe1/statuses/150126...
# 1  2022-03-08  06:27PM  https://twitter.com/cally_callly/statuses/1501...
# 2  2022-03-08  06:26PM  https://twitter.com/Mcpsalmmy1/statuses/150126...
# 3  2022-03-08  05:56PM  https://twitter.com/AIPLF_Ireland/statuses/150...
# 4  2022-03-08  03:13PM  http://twitter.com/CryptoJ1mbo/statuses/150121...
#
#                                         Hit Sentence   Source     Influencer  \
# 0  QT @pancakewafflet1: Paris brun 👍 ; what color...  Twitter     macymaybe1
# 1  RT @SaitamaUniverse: QT @jbrizendine: The spee...  Twitter   cally_callly
# 2  @PancakeChubby @UnitedStandMUFC Thank me later...  Twitter     mcpsalmmy1
# 3  RT @domballyfermot: *On fait des crêpes!!!!*🇫🇷...  Twitter  aiplf_ireland
# 4  RT @WatcherGuru: JUST IN: PancakeSwap, the #1 ...  Twitter    CryptoJ1mbo
#
# ...

# %%
comment_words = '' 
stopwords = set(STOPWORDS)
stopwords = ['nan', 'NaN', 'Nan', 'NAN','QT','RT',"https",'co','slut','t','yup_dilfs'] + list(STOPWORDS)

# %%
values = pancake_mentions['Hit Sentence'].values

for val in values: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    comment_words += ' '.join(tokens)+' '

# %%
facecolor = 'white'

wordcloud = WordCloud(width=1000, height=600, 
            background_color=facecolor, 
            stopwords=stopwords,
            min_font_size=15).generate(comment_words)

# %%
plt.figure(figsize=(10,6), facecolor=facecolor) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.tight_layout(pad=2)
# Out:
# <img src="data:image/png;base64,..." width="1000">
